# %%
# Import dependencies
import pandas as pd
from pathlib import Path

import re
from datetime import datetime

# %%
# Import Oct 2023 dataset
oct_path = Path("resources/JC-202310-citibike-tripdata.csv")
oct_df = pd.read_csv(oct_path)

# Import Nov 2022 dataset
nov_path = Path("resources/JC-202211-citibike-tripdata.csv")
nov_df = pd.read_csv(nov_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[147], line 7
#       5 # Import Nov 2022 dataset
#       6 nov_path = Path("resources/JC-202211-citibike-tripdata.csv")
# ----> 7 nov_df = pd.read_csv(nov_path)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'resources/JC-202211-citibike-tripdata.csv'

# %%
# Check the Oct 2023 dataset columns
oct_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97584 entries, 0 to 97583
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             97584 non-null  object
#  1   rideable_type       97584 non-null  object
#  2   started_at          97584 non-null  object
#  3   ended_at            97584 non-null  object
#  4   start_station_name  97579 non-null  object
#  5   start_station_id    97579 non-null  object
#  6   end_station_name    97207 non-null  object
#  7   end_station_id      97207 non-null  object
#  8   start_lat           97584 non-null  float64
#  9   start_lng           97584 non-null  float64
#  10  end_lat             97497 non-null  float64
#  11  end_lng             97497 non-null  float64
#  12  member_casual       97584 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 9.7+ MB

# %%
# Check the Nov 2022 dataset columns
nov_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72709 entries, 0 to 72708
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             72709 non-null  object
#  1   rideable_type       72709 non-null  object
#  2   started_at          72709 non-null  object
#  3   ended_at            72709 non-null  object
#  4   start_station_name  72699 non-null  object
#  5   start_station_id    72699 non-null  object
#  6   end_station_name    72430 non-null  object
#  7   end_station_id      72430 non-null  object
#  8   start_lat           72709 non-null  float64
#  9   start_lng           72709 non-null  float64
#  10  end_lat             72609 non-null  float64
#  11  end_lng             72609 non-null  float64
#  12  member_casual       72709 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 7.2+ MB

# %%
# Find all the CSVs in the resources directory
csv_paths = []
for path in Path("resources").iterdir():
    csv_paths.append(path)

# Create a DataFrame from all the CSVs
combined_df = pd.concat((pd.read_csv(filename) for filename in csv_paths))
combined_df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[148], line 7
#       4     csv_paths.append(path)
#       6 # Create a DataFrame from all the CSVs
# ----> 7 combined_df = pd.concat((pd.read_csv(filename) for filename in csv_paths))
#       8 combined_df.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/reshape/concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/reshape/concat.py:422, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     420     objs = [objs[k] for k in keys]
#     421 else:
# --> 422     objs = list(objs)
#     424 if len(objs) == 0:
#     425     raise ValueError("No objects to concatenate")
#
# Cell In[148], line 7, in <genexpr>(.0)
#       4     csv_paths.append(path)
#       6 # Create a DataFrame from all the CSVs
# ----> 7 combined_df = pd.concat((pd.read_csv(filename) for filename in csv_paths))
#       8 combined_df.head()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1753, in TextFileReader._make_engine(self, f, engine)
#    1750     raise ValueError(msg)
#    1752 try:
# -> 1753     return mapping[engine](f, **self.options)
#    1754 except Exception:
#    1755     if self.handles is not None:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:79, in CParserWrapper.__init__(self, src, **kwds)
#      76     kwds.pop(key, None)
#      78 kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> 79 self._reader = parsers.TextReader(src, **kwds)
#      81 self.unnamed_cols = self._reader.unnamed_cols
#      83 # error: Cannot determine type of 'names'
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:547, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:636, in pandas._libs.parsers.TextReader._get_header()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/_libs/parsers.pyx:1965, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 3131: invalid start byte

# %%
# Display the columns to identify null count
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975819 entries, 0 to 48584
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             975819 non-null  object
#  1   rideable_type       975819 non-null  object
#  2   started_at          975819 non-null  object
#  3   ended_at            975819 non-null  object
#  4   start_station_name  975737 non-null  object
#  5   start_station_id    975737 non-null  object
#  6   end_station_name    972491 non-null  object
#  7   end_station_id      972491 non-null  object
#  8   start_lat           975819 non-null  float64
#  9   start_lng           975819 non-null  float64
#  10  end_lat             974755 non-null  float64
#  11  end_lng             974755 non-null  float64
#  12  member_casual       975819 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 104.2+ MB

# %%
# Drop all rows which have a null value
clean_df = combined_df.dropna(how="any").reset_index(drop=True)

clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 972488 entries, 0 to 972487
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             972488 non-null  object
#  1   rideable_type       972488 non-null  object
#  2   started_at          972488 non-null  object
#  3   ended_at            972488 non-null  object
#  4   start_station_name  972488 non-null  object
#  5   start_station_id    972488 non-null  object
#  6   end_station_name    972488 non-null  object
#  7   end_station_id      972488 non-null  object
#  8   start_lat           972488 non-null  float64
#  9   start_lng           972488 non-null  float64
#  10  end_lat             972488 non-null  float64
#  11  end_lng             972488 non-null  float64
#  12  member_casual       972488 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 96.5+ MB

# %%
clean_df = clean_df.astype({
    'started_at': 'datetime64[ns]',
    'ended_at': 'datetime64[ns]'
})

clean_df.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  E2E964A161F786AB  classic_bike 2023-08-07 19:37:47 2023-08-07 19:41:14
# 1  0660F2E48E3BB87F  classic_bike 2023-08-01 13:16:22 2023-08-01 13:26:02
# 2  940FC7C675232897  classic_bike 2023-08-15 17:28:23 2023-08-15 17:50:35
# 3  E967660CC5CD585B  classic_bike 2023-08-01 12:44:24 2023-08-01 12:49:45
# 4  D997CB0B855FE2D6  classic_bike 2023-08-08 12:31:16 2023-08-08 12:40:18
#
#            start_station_name start_station_id  \
# 0             6 St & Grand St            HB302
# 1             6 St & Grand St            HB302
# 2            Heights Elevator            JC059
# 3  Hoboken Ave at Monmouth St            JC105
# 4  Hoboken Ave at Monmouth St            JC105
#
#                           end_station_name end_station_id  start_lat  \
# 0                       Madison St & 10 St          HB503  40.744398
# 1                          6 St & Grand St          HB302  40.744398
# 2                         Heights Elevator          JC059  40.748721
# 3  Hoboken Terminal - River St & Hudson Pl          HB102  40.735279
# 4  Hoboken Terminal - River St & Hudson Pl          HB102  40.735208
#
#    start_lng    end_lat    end_lng member_casual
# 0 -74.034501  40.749943 -74.035865        member
# 1 -74.034501  40.744398 -74.034501        member
# 2 -74.040480  40.748716 -74.040443        member
# 3 -74.046830  40.736068 -74.029127        member
# 4 -74.046964  40.736068 -74.029127        member

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 972488 entries, 0 to 972487
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             972488 non-null  object
#  1   rideable_type       972488 non-null  object
#  2   started_at          972488 non-null  datetime64[ns]
#  3   ended_at            972488 non-null  datetime64[ns]
#  4   start_station_name  972488 non-null  object
#  5   start_station_id    972488 non-null  object
#  6   end_station_name    972488 non-null  object
#  7   end_station_id      972488 non-null  object
#  8   start_lat           972488 non-null  float64
#  9   start_lng           972488 non-null  float64
#  10  end_lat             972488 non-null  float64
#  11  end_lng             972488 non-null  float64
#  12  member_casual       972488 non-null  object
# dtypes: datetime64[ns](2), float64(4), object(7)
# memory usage: 96.5+ MB

# %%
start_stations = clean_df['start_station_name'].value_counts()

# %%
start_stations[start_stations.values < 100]
# Out:
# Broadway & W 56 St          8
# Cleveland Pl & Spring St    4
# 5 Ave & E 87 St             4
# W 41 St & 8 Ave             4
# John St & William St        3
#                            ..
# E 97 St & 3 Ave             1
# E 25 St & 2 Ave             1
# Division St & Bowery        1
# 8 Ave & W 52 St             1
# Walker St & Baxter St       1
# Name: start_station_name, Length: 225, dtype: int64

# %%
pattern = 'Walker St'
for station in start_stations.index:
    if len(re.findall(pattern, station)) > 0:
        print(station)
# Out:
# 6 Ave & Walker St
# Walker St & Baxter St

# %%
same_startend = clean_df.loc[(clean_df['start_lat'] == clean_df['end_lat']) & (clean_df['start_lng'] == clean_df['end_lng'])]
same_startend
# Out:
#                  ride_id  rideable_type          started_at  \
# 1       0660F2E48E3BB87F   classic_bike 2023-08-01 13:16:22
# 10      03B9C22973B055BF  electric_bike 2023-08-02 13:23:34
# 11      6A1209C04341249B  electric_bike 2023-08-02 13:25:13
# 13      1DEF9C2A826DF529   classic_bike 2023-08-14 17:43:22
# 38      AA55978A1EBD9347   classic_bike 2023-08-15 18:44:11
# ...                  ...            ...                 ...
# 972432  E4E1D6B94452AF3D   classic_bike 2022-12-23 15:14:13
# 972442  FBF8CB546EA8FFC2   classic_bike 2022-12-21 17:59:11
# 972478  ACFD566729F5213E   classic_bike 2022-12-30 18:07:49
# 972481  5A27145BDBF52E24   classic_bike 2022-12-18 16:15:48
# 972482  E95B60643D26620A   classic_bike 2022-12-10 13:13:06
#
#                   ended_at                start_station_name start_station_id  \
# 1      2023-08-01 13:26:02                   6 St & Grand St            HB302
# 10     2023-08-02 13:24:39                    Jackson Square            JC063
# 11     2023-08-02 13:25:36                    Jackson Square            JC063
# 13     2023-08-14 18:27:11        Hoboken Ave at Monmouth St            JC105
# 38     2023-08-15 19:19:42                    Pershing Field            JC024
# ...                    ...                               ...              ...
# 972432 2022-12-23 16:59:10                    Riverview Park            JC057
# 972442 2022-12-21 17:59:47                    Riverview Park            JC057
# 972478 2022-12-30 18:30:09  City Hall - Washington St & 1 St            HB105
# 972481 2022-12-18 16:15:57                      Manila & 1st            JC082
# 972482 2022-12-10 13:13:22  City Hall - Washington St & 1 St            HB105
#
#                         end_station_name end_station_id  start_lat  start_lng  \
# 1                        6 St & Grand St          HB302  40.744398 -74.034501
# 10                        Jackson Square          JC063  40.711130 -74.078900
# 11                        Jackson Square          JC063  40.711130 -74.078900
# 13            Hoboken Ave at Monmouth St          JC105  40.735208 -74.046964
# 38                        Pershing Field          JC024  40.742677 -74.051789
# ...                                  ...            ...        ...        ...
# 972432                    Riverview Park          JC057  40.744319 -74.043991
# 972442                    Riverview Park          JC057  40.744319 -74.043991
# 972478  City Hall - Washington St & 1 St          HB105  40.737360 -74.030970
# 972481                      Manila & 1st          JC082  40.721651 -74.042884
# 972482  City Hall - Washington St & 1 St          HB105  40.737360 -74.030970
#
#           end_lat    end_lng member_casual
# 1       40.744398 -74.034501        member
# 10      40.711130 -74.078900        member
# 11      40.711130 -74.078900        member
# 13      40.735208 -74.046964        casual
# 38      40.742677 -74.051789        member
# ...           ...        ...           ...
# 972432  40.744319 -74.043991        casual
# 972442  40.744319 -74.043991        casual
# 972478  40.737360 -74.030970        casual
# 972481  40.721651 -74.042884        casual
# 972482  40.737360 -74.030970        member
#
# [44915 rows x 13 columns]

# %%
duration = same_startend['ended_at'] - same_startend['started_at']
duration
# Out:
# 1        0 days 00:09:40
# 10       0 days 00:01:05
# 11       0 days 00:00:23
# 13       0 days 00:43:49
# 38       0 days 00:35:31
#                ...
# 972432   0 days 01:44:57
# 972442   0 days 00:00:36
# 972478   0 days 00:22:20
# 972481   0 days 00:00:09
# 972482   0 days 00:00:16
# Length: 44915, dtype: timedelta64[ns]

# %%
duration.sort_values()
# Out:
# 195818   -1 days +23:38:36
# 195819   -1 days +23:39:24
# 877301   -1 days +23:59:59
# 195816     0 days 00:00:00
# 163375     0 days 00:00:00
#                 ...
# 665749     0 days 22:32:30
# 745749     0 days 22:57:26
# 163479     1 days 00:03:04
# 862289     1 days 00:38:26
# 170217     2 days 02:10:36
# Length: 44915, dtype: timedelta64[ns]

# %%
same_startend[same_startend.index == 170217]
# Out:
#                  ride_id rideable_type          started_at  \
# 170217  2BF79246D444D0EC   docked_bike 2022-11-26 15:27:27
#
#                   ended_at  start_station_name start_station_id  \
# 170217 2022-11-28 17:38:03  Liberty Light Rail            JC052
#
#           end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 170217  Liberty Light Rail          JC052  40.711242 -74.055701  40.711242
#
#           end_lng member_casual
# 170217 -74.055701        casual

# %%
invalid = same_startend.loc[same_startend['ended_at'] == same_startend['started_at']]
len(invalid)
# Out:
# 33

# %%
# Less than one minute in duration
same_startend.loc[duration < pd.Timedelta(minutes=1)]
# Out:
#                  ride_id  rideable_type          started_at  \
# 11      6A1209C04341249B  electric_bike 2023-08-02 13:25:13
# 120     8EF5194B604BF30E   classic_bike 2023-08-09 12:12:14
# 121     06A71E513DA709FD   classic_bike 2023-08-27 11:06:34
# 232     9A5CF8CEFCB5A0F1  electric_bike 2023-08-12 09:20:32
# 247     A2542561E767B213   classic_bike 2023-08-11 21:34:32
# ...                  ...            ...                 ...
# 972345  F5C94C4C38A64E0E   classic_bike 2022-12-13 17:58:52
# 972421  CD0972D617A89F01  electric_bike 2022-12-29 12:59:42
# 972442  FBF8CB546EA8FFC2   classic_bike 2022-12-21 17:59:11
# 972481  5A27145BDBF52E24   classic_bike 2022-12-18 16:15:48
# 972482  E95B60643D26620A   classic_bike 2022-12-10 13:13:06
#
#                   ended_at                       start_station_name  \
# 11     2023-08-02 13:25:36                           Jackson Square
# 120    2023-08-09 12:12:20  Hoboken Terminal - River St & Hudson Pl
# 121    2023-08-27 11:06:46  Hoboken Terminal - River St & Hudson Pl
# 232    2023-08-12 09:20:40                      Leonard Gordon Park
# 247    2023-08-11 21:34:57                      Leonard Gordon Park
# ...                    ...                                      ...
# 972345 2022-12-13 17:59:23         City Hall - Washington St & 1 St
# 972421 2022-12-29 13:00:02                           Riverview Park
# 972442 2022-12-21 17:59:47                           Riverview Park
# 972481 2022-12-18 16:15:57                             Manila & 1st
# 972482 2022-12-10 13:13:22         City Hall - Washington St & 1 St
#
#        start_station_id                         end_station_name  \
# 11                JC063                           Jackson Square
# 120               HB102  Hoboken Terminal - River St & Hudson Pl
# 121               HB102  Hoboken Terminal - River St & Hudson Pl
# 232               JC080                      Leonard Gordon Park
# 247               JC080                      Leonard Gordon Park
# ...                 ...                                      ...
# 972345            HB105         City Hall - Washington St & 1 St
# 972421            JC057                           Riverview Park
# 972442            JC057                           Riverview Park
# 972481            JC082                             Manila & 1st
# 972482            HB105         City Hall - Washington St & 1 St
#
#        end_station_id  start_lat  start_lng    end_lat    end_lng  \
# 11              JC063  40.711130 -74.078900  40.711130 -74.078900
# 120             HB102  40.736068 -74.029127  40.736068 -74.029127
# 121             HB102  40.736068 -74.029127  40.736068 -74.029127
# 232             JC080  40.745910 -74.057271  40.745910 -74.057271
# 247             JC080  40.745910 -74.057271  40.745910 -74.057271
# ...               ...        ...        ...        ...        ...
# 972345          HB105  40.737360 -74.030970  40.737360 -74.030970
# 972421          JC057  40.744319 -74.043991  40.744319 -74.043991
# 972442          JC057  40.744319 -74.043991  40.744319 -74.043991
# 972481          JC082  40.721651 -74.042884  40.721651 -74.042884
# 972482          HB105  40.737360 -74.030970  40.737360 -74.030970
#
#        member_casual
# 11            member
# 120           casual
# 121           member
# 232           member
# 247           casual
# ...              ...
# 972345        member
# 972421        member
# 972442        casual
# 972481        casual
# 972482        member
#
# [11438 rows x 13 columns]

# %%
# Longer duration rides
same_startend.loc[duration > pd.Timedelta(hours=24)]
# Out:
#                  ride_id  rideable_type          started_at  \
# 163479  E03FA79F6F14F3EC  electric_bike 2022-11-09 16:19:35
# 170217  2BF79246D444D0EC    docked_bike 2022-11-26 15:27:27
# 862289  2C8C9870A5C695A8  electric_bike 2023-07-16 00:21:06
#
#                   ended_at       start_station_name start_station_id  \
# 163479 2022-11-10 16:22:39  Bergen Ave & Stegman St            JC108
# 170217 2022-11-28 17:38:03       Liberty Light Rail            JC052
# 862289 2023-07-17 00:59:32     12 St & Sinatra Dr N            HB201
#
#                end_station_name end_station_id  start_lat  start_lng  \
# 163479  Bergen Ave & Stegman St          JC108  40.706575 -74.086701
# 170217       Liberty Light Rail          JC052  40.711242 -74.055701
# 862289     12 St & Sinatra Dr N          HB201  40.750604 -74.024020
#
#           end_lat    end_lng member_casual
# 163479  40.706575 -74.086701        casual
# 170217  40.711242 -74.055701        casual
# 862289  40.750604 -74.024020        casual

# %%
clean_df['rideable_type'].value_counts()
# Out:
# classic_bike     820585
# electric_bike    149498
# docked_bike        2405
# Name: rideable_type, dtype: int64

# %%
clean_df.loc[clean_df['rideable_type'] == "docked_bike"]
# Out:
#                  ride_id rideable_type          started_at  \
# 112471  858E0A116A970C22   docked_bike 2023-02-11 22:18:24
# 112477  ADDFD555C51DBDAB   docked_bike 2023-02-26 18:19:16
# 112587  674EFD4B099F0C7D   docked_bike 2023-02-21 16:58:30
# 112656  9C29738101B6364F   docked_bike 2023-02-24 03:11:33
# 112670  4603DD7372EE3B68   docked_bike 2023-02-24 20:54:26
# ...                  ...           ...                 ...
# 970908  755CFC38E92A64CB   docked_bike 2022-12-10 16:08:10
# 970942  2F58B95E6297CC78   docked_bike 2022-12-20 16:03:32
# 971156  332E55456B046606   docked_bike 2022-12-18 19:11:34
# 971260  8AD2045017767897   docked_bike 2022-12-05 15:06:58
# 972175  DAE3B3D0440FED09   docked_bike 2022-12-23 14:59:20
#
#                   ended_at                       start_station_name  \
# 112471 2023-02-11 22:37:38                            Hamilton Park
# 112477 2023-02-26 18:52:39                     8 St & Washington St
# 112587 2023-02-21 17:03:17                            Washington St
# 112656 2023-02-24 03:16:47                             Newport PATH
# 112670 2023-02-24 21:21:44                            Hamilton Park
# ...                    ...                                      ...
# 970908 2022-12-10 16:22:09                   Clinton St & Newark St
# 970942 2022-12-21 08:34:54  Hoboken Terminal - River St & Hudson Pl
# 971156 2022-12-19 09:55:12  Hoboken Terminal - River St & Hudson Pl
# 971260 2022-12-05 15:12:13         City Hall - Washington St & 1 St
# 972175 2022-12-23 16:58:46                         Heights Elevator
#
#        start_station_id       end_station_name end_station_id  start_lat  \
# 112471            JC009   8 St & Washington St          HB603  40.727596
# 112477            HB603   8 St & Washington St          HB603  40.745984
# 112587            JC098               Grand St          JC102  40.724294
# 112656            JC066          Hamilton Park          JC009  40.727224
# 112670            JC009          Hamilton Park          JC009  40.727596
# ...                 ...                    ...            ...        ...
# 970908            HB409            Dixon Mills          JC076  40.737430
# 970942            HB102  11 St & Washington St          HB502  40.736068
# 971156            HB102  11 St & Washington St          HB502  40.736068
# 971260            HB105   8 St & Washington St          HB603  40.737360
# 972175            JC059         Riverview Park          JC057  40.748716
#
#         start_lng    end_lat    end_lng member_casual
# 112471 -74.044247  40.745984 -74.028199        casual
# 112477 -74.028199  40.745984 -74.028199        casual
# 112587 -74.035483  40.715178 -74.037683        casual
# 112656 -74.033759  40.727596 -74.044247        casual
# 112670 -74.044247  40.727596 -74.044247        casual
# ...           ...        ...        ...           ...
# 970908 -74.035710  40.721630 -74.049968        casual
# 970942 -74.029127  40.749985 -74.027150        casual
# 971156 -74.029127  40.749985 -74.027150        casual
# 971260 -74.030970  40.745984 -74.028199        casual
# 972175 -74.040443  40.744319 -74.043991        casual
#
# [2405 rows x 13 columns]
